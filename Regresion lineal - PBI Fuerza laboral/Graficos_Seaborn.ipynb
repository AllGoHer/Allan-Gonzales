# %%
import pandas as pd

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt

# %%
datos_mexico= pd.read_csv('C:\\Users\\ALLAN\\Desktop\\Business Analitics con Python y ChatGPT\\datosmexico.csv')

# %%
datos_mexico
# Out:
#     Label  PIBperCapita  FuerzaLaboral
# 0    2019  10145.152630      64.426002
# 1    2018   9857.007487      64.346001
# 2    2017   9434.378179      64.043999
# 3    2016   8875.082069      64.164001
# 4    2015   9753.400562      64.135002
# 5    2014  11076.134110      64.025002
# 6    2013  10865.687290      64.628998
# 7    2012  10376.090500      64.778000
# 8    2011  10341.500240      64.024002
# 9    2010   9399.964709      63.882999
# 10   2009   8104.922573      64.059998
# 11   2008  10119.821060      64.075996
# 12   2007   9719.927864      64.397003
# 13   2006   9125.387739      64.232002
# 14   2005   8321.859856      63.403000
# 15   2004   7525.487461      62.433998
# 16   2003   7120.372121      61.799000
# 17   2002   7650.931864      61.382000
# 18   2001   7613.142978      61.922001
# 19   2000   7232.910681      62.498001
# 20   1999   6230.697201      62.543999
# 21   1998   5555.711857      63.259998
# 22   1997   5370.244638      63.564999
# ...

# %%
sns.scatterplot(x='FuerzaLaboral', y='PIBperCapita', data =datos_mexico )
plt.show()

# %%
plt.figure(figsize=(10,5), dpi=300)
sns.scatterplot(x='FuerzaLaboral', y='PIBperCapita', data =datos_mexico )
plt.show()

# %%
plt.figure(figsize=(10,5), dpi=300)
sns.scatterplot(x='FuerzaLaboral', y='PIBperCapita', data =datos_mexico )
plt.ylim(3000,12000)
plt.xlim(59,66)
plt.ylabel('PIB per Capita en USD')
plt.xlabel('Fuerza Laboral como % del Total de la Poblacion')
plt.show()
